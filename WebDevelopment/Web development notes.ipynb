# %% [markdown]
# # Web development notes
# This notebook supports the notes for HTML and WEB development for FASE
# ![image.png](attachment:95b4439d-71b0-4ff1-8bf4-8c2541f4eaa8.png)

# %% [markdown]
# Additionally if we were dealing with a dynaic website then the content is developed with interactions between an app and a database  in what is considered the backend. The code that develops the response is from applications running on the server and can be written in multiple languages depending on the need, node, php python .net etc etc

# %% [markdown]
# ## Structure
# The pages that are served after being created using Content from HTML (nouns), Presentation from CSS(adjectives) and interactability from Javascript verbs simply put
# HTML - `<p><\p>`
# CSS - `p {color: red }`
# JS - `p.hide()`

# %% [markdown]
# ## Basic workflow
# Create a development workspace to hold the work, the default page is index.html file for the html
# in vscode we can build out boilerplate by cerating the file and in visual studio executing `
#
# Some extensions that are of use in this are :
# - prettier We need to set this as the default formatter in the config section
# - We need to also set the format on save option
# - We need to set the auto save on focus change
#
# Optional set theme if needed back in extensions One Monokai
# We can see the results by open in chrome or otherwise

# %% [markdown]
# ## Basic HTML tag structure:
# ![image.png](attachment:d47ef333-b82e-4d4e-86ad-0c7dc9f28a23.png)

# %% [markdown]
# ## Setting up a development environment
# Pull in vscode if you dont already have it. Install the following extensions:
# 1. prettier
# 2. Set the prettier as the formatter , in settings look for default format then set the default formatter to prettier
# 3. Configure the format on save option
# 4. Configure the auto save on focus change
# 5. Configure the tab size to 2
# 6. Optional Install colour scheme One Monokai in extensions
#
# ### Additional
# 1. image preview - inline image preview
# 2. color highlight - useful in css for visualising colours
# 3. Auto Rename Tag - automatically updates the corresponding tag
# 4. Live server

# %% [markdown]
# ## Creating a page
# We can do this either by taking the boiler plate or making it ourselves.
# 1. Create a ne file in the work area called index.html
# 2. create the type declaration
# 3. create the html element
# 4. create the head lement
# 5. create the body element
#
# The head element is not visible when the page is renedered, it contains metadata about the document, title, references that sort of thing. i.e it desctibes the document

# %% [markdown]
# ## Build out a basic page
# Build the basic pge showing elements used and comparisons
# html, head, body, paragraphgs, lists, emphasis.
# ### Images
# Note we use the src attribute and we set the alt attribute, this lets users know what they are looking at but also lets search engines know what the image is. Also it allows blind eople to be aware of what is there and accessibility is important. We can prove it's usefulness by mutilating the path to the resource and the browser will show the alt text instead.
# Note also that we can directly control attributes if we want to by setting sizes.

# %% [markdown]
# ## Additional attributes
# 1. HTML lang which can be any of the known national languages for us en
# 2. set the character class used in the document in the  meta tag in the head element

# %% [markdown]
# ## Hyperlinks
# These are a fundamental of the whole thing, that they allow for linking data tot the document links can go to somewhere in our own website or externally. We do this by implementing an anchor element.
# by default it opens in the same window, but we may want it to open a new tab which we do by specifying the target attribute as _blank
# ### creating internal links
# As for standard anchor but referencing an internal page path
# ***Notice*** that there has to be a link reference for the ancho to work as an anchor. If I want to set hem up as [placeholders then I use the # as the link

# %% [markdown]
# ## Adding HTML 5
# HTML 5 offers more containters to aid in logically structureing the content
# For links in the top bar, these are navigation links and there is a container for this called nav, there is no real change in the site display for this, but there will be, and the links are logically contained.
# ### header
# The header represents a container for introductory content or a set of navigational links. Note: You can have several <header> elements in one HTML document. However, `<header>` cannot be placed within a `<footer>`, `<address>` or another `<header>` element.
#
# ### article
# The `<article>` tag specifies independent, self-contained content.
#
# An article should make sense on its own and it should be possible to distribute it independently from the rest of the site.
#
# Potential sources for the `<article>` element:
#
# Forum post
# Blog post
# News story
# Note: The `<article>` element does not render as anything special in a browser. However, you can use CSS to style the `<article>` element.
#
# ### footer
# This element allows for a page footer  in the example we can use web symbols the one used here is copyright a full list available from `https://www.freeformatter.com/html-entities.html`

# %% [markdown]
# ## Semantic HTML
# One of the goals of HTML 5 was to apply more meaning to the tagging structure, in our case we exampled that by observing the use of strong and b as achieving the same aim, but strong applied a degree of meaning to the content it was working with. The other containers we used are similarly there for that reason, nav, header, footer. We could represent the same with non semantic HTML `<div>` for example, we only use the div element when we do not want to attach a certain meaning to a certain container.
# ***Note*** it is important to note that the HTML5 symantics allow search engines and other applications like readers to understand the page better.

# %% [markdown]
# ## Adding information that is not directly to do with the page
# There are times when we need to add information that does not belong to the content but is related to it, for that html5 provides the `<aside>` element, its not in the article and its not in the footer normally its on the side of the main  content but not always

# %% [markdown]
# # CSS
# ![image.png](attachment:2f01b2fa-a5a9-4b3b-a7e9-9f888655a674.png)
#
# CSS can be written as:
# - inline
# - internal
# - external
#
# Generally, we do not implement css inline, it is not good practice but an example would be `<h1 style="color: blue">The Tech Blog</h1>`
#
# To declare internal we add the reference to it in the head element as `<style>` tag as the reference, everything in the style tag is the css code itself, where we use that pattern :
# - selector
# - attributes
# `    <style>
#       h1 {
#         color: rgb(105, 105, 195);
#       }
#     </style>`
#   However this also is not practical for large CSS settings

# %% [markdown]
# ## the CSS file
# the external approach is preferred; this is the CSS file that is referenced in the head element and provides the formatting rules for everything that it is referred to.
# `<link href="style.css" rel="stylesheet"/>`
# The required rel attribute specifies the relationship between the current document and the linked document/resource.
#
# ### length
# Note that when defining sizes, such as font sizes, images, et-al, this can be done in multiple ways: percentage, pixels, em
# ### font-family
# this is the defionition of the font that is to be used, note that you cant just use fonts installed on your machine as they may not be installed on others
# ### line-height
# this overrides the space between the lines in the element selected
#
# ### Inheritance
# Notice as things change in p that the contained elements such as a also take the values of the parent
#
# ## Styling lists
# Usually better to style the li rather than ol or ul

# %% [markdown]
# ## combining selectors
# If there are common properties set over lements then it is reasonable to combine the selctors for them, in the example tha twe are using, that will be something like, all elements are sans-serif. One way of doing that is simply a list of selectors , delimited with a comma
# The other way is referencing something within another selector, in our example, the footer has thecopywrite set, thisis normally a lot smaller than the rest of the text and so it will need addressing. this is simply done by styling at footer p

# %% [markdown]
# ## Referencing using classes and Ids
# If I wanted to target a specific element then I would use id to increase the granularity of referencing. set with the id= attribute in the hatml, and called by the # selector in the css
# IN our example, we do it for author and copyright
# Note that id cannot be replicated, if we wanted to do that we have to use class
#
# In the example I add related-author
#
# For class addressing I use .
#
# ***Note***  `<p>` element has been styled multiple times, so how is the one that is shown chosen. THe truth is that all the styles are applied this will be looked at later
#
# ### Final change
# Update the list to remove the bullets

# %% [markdown]
# ## Exercise
# Create a new page to house a product according to the specification
# You are required to make a product page for the Exelsior Fountain Pen. The image is included.
# The product page should have a heading with the pen title in it,
# a picture of the product:
# 'exelsior-fountain-pen.jpg'
# a strapline: 'The pride of our fountain pen range'
# a price: £250
# Free shipping
#
# Product information
# 'The Exelsior Fountain pen is a delight and a marvel, delightful to write with as it glides over the page and a mrvel to all who percieve it's grace and beauty.'
# A section for product details containing :
#
# Product features
#
# Lightweight design
# Superior writing comfort
#
# A Button with the text 'add To Cart' this does not need to be functional at the moment

# %% [markdown]
# ## Colours
# Standard colour ranges in RGB
# ![image.png](attachment:5000c334-4594-4bd5-a688-87422f62ad27.png)
# Colour Ranges but with alpha channel transparency
#
# ![image.png](attachment:ab42bc46-0aa6-4ad8-834e-566a66d32642.png)

# %% [markdown]
# ## Applying colour to the elements
#
# ***Note*** When applying colours or some other attributes in style to an object it is not always the case that the property is inherited by all children in our example We use a border on the body border-top, this only applies to that element and not it's children

# %% [markdown]
# ## Applying global style
# We can set conditions globally by using the universl selector * and then style individual elements as we need.
# ### Inheritance
# Note that if a property of a parent applies to a child then it does soby default unless it is overwritten by a style specifically to that element by ID or CLASS.

# %% [markdown]
# ## Exercise
# Style the product page made earlier:
# All text should be sans-serif
#
# Article:
# - a solid border 4px colour black
# -
# The product Title:
# - should be all in upper case
# - have a light grey background
# - should appear in the centre of the page
# The price text should be 24px and bold
# The shipping information should be :
# - uppercase
# - 12px
# - bold
# - the font should be dark grey
# The Product information:
# - Title
# - - Upper case
#   - 16px
# - Information list
# - The list should have square bullets
# Button:
# - background colour black
# - text colour white
# - no border
# - Upper case
# - size 20px
# - cursor should change to pointer when hovering over the button
# - the button should change colour when the mouse is over it
#
# Dont forget to use selectors for this
